# %% [markdown]
# # GRIP@The Sparks Foundation
#
# # Data Science and Business Analytics
# # TASK 1: Prediction using Supervised ML
# # By: Pranavi Kakani

# %% [markdown]
# This task requires us to predict the percentage of a student based on the number of study hours.

# %% [markdown]
# Firstly, importing all necessary libraries -

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Now, reading the data set using pandas

# %%
url = "http://bit.ly/w-data"
data = pd.read_csv(url)
data.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %% [markdown]
# In order to identify any possible pattern, we now plot this data using matplotlib

# %%
data.plot(x='Hours', y='Scores', style='*', ms = 15, mec = "b")  
plt.title('Hours vs Percentage')  
plt.xlabel('Hours')  
plt.ylabel('Percentage')  
plt.show()

# %% [markdown]
# Now importing all the libraries we need for preparing the data and training the model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Preparing the data by splitting it into X,Y

# %%
X = data.iloc[:, :-1].values  
Y = data.iloc[:, 1].values
print("X =\n",X,"\n")
print("Y =\n",Y)
# Out:
# X =
#  [[2.5]
#  [5.1]
#  [3.2]
#  [8.5]
#  [3.5]
#  [1.5]
#  [9.2]
#  [5.5]
#  [8.3]
#  [2.7]
#  [7.7]
#  [5.9]
#  [4.5]
#  [3.3]
#  [1.1]
#  [8.9]
#  [2.5]
#  [1.9]
#  [6.1]
#  [7.4]
#  [2.7]
#  [4.8]
#  [3.8]
#  [6.9]
#  [7.8]]
#
# Y =
#  [21 47 27 75 30 20 88 60 81 25 85 62 41 42 17 95 30 24 67 69 30 54 35 76
#  86]

# %% [markdown]
# Defining training and testing sets

# %%
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size = 0.1)
lnr = LinearRegression()
lnr.fit(X_train, y_train ) 

predicted_y = lnr.predict(X_test)
print("Predicted Y records:")
print(predicted_y)
# Out:
# Predicted Y records:
# [52.58138515 13.33421697 29.03308424]

# %% [markdown]
# Visualising the linear regression using matplotlib

# %%
plt.figure(figsize=(7,3))
reg = lnr.coef_*X+lnr.intercept_
plt.scatter(X, Y)
plt.plot(X, reg)
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.title("Prediction")
plt.show()

# %% [markdown]
# Calculating the mean absolute error and max error for the model -

# %%
from sklearn import metrics
from sklearn.metrics import mean_squared_error
from math import sqrt
print('Mean Absolute Error:', metrics.mean_absolute_error(Y_test, predicted_Y))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Y_test, predicted_Y)))
# Out:
# Mean Absolute Error: 33.35509047499988
# Root Mean Squared Error: 34.81968547958348

# %% [markdown]
# Calculating the closeness to the calculated value -

# %%
y_pred = lnr.predict(X_test)
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})  
df
# Out:
#    Actual  Predicted
# 0      47  52.581385
# 1      17  13.334217
# 2      25  29.033084

# %% [markdown]
# Computing the prediction for 9.25 hours a day -

# %%
hours = 9.25
scores = lnr.predict([[hours]])
print("No of Hours = {}".format(hours))
print("Predicted Score = {}".format(scores[0]))
# Out:
# No of Hours = 9.25
# Predicted Score = 93.30032214522282

# %% [markdown]
# # Conclusion

# %% [markdown]
# The given data set "http://bit.ly/w-data" consists of students' percentage data with respect to the number of hours the corresponding student spent studying. After initial plotting and organising the data for visualisation using matplotlib library, it was used to train a machine learning model to predict the percentage of a student who spent 9.25 hours studying.
#
# The model was succesfully implemented and gave the result as -
# The predicted percentage score of a student who spent 9.25 hours a day studying is 93.300322.
